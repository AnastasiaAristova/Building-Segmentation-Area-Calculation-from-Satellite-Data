# %% [markdown]
# # Запуск сервера

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 93.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 126.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.3 MB/s eta 0:00:00

# %% [markdown]
# localtunnel – инструмент, который создает публичный URL для локального сервера.

# %%
# !npm install localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹
# added 22 packages in 2s
# ⠹
# ⠹3 packages are looking for funding
# ⠹  run `npm fund` for details
# ⠹

# %% [markdown]
# Получить публичный IPv4-адрес, который использует Google Colab для выхода в интернет. Его необходимо скопировать и вставить в нужное поле по ссылке, которая появится при запуске следующей команды.

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.16.129.33

# %% [markdown]
# Запуск Streamlit приложения. В кавычках указан путь к скрипту Streamlit. Знак & указывает на то, что приложение запустится в фоновом режиме.
#
# Стандартный порт для Streamlit - 8501. Т.к. у Colab нет прямого доступа к данному порту, необходимо использовать инструмент localtunnel.
#
# После запуска перейдите по ссылке "your url is: ..."

# %%
# !streamlit run '/content/gdrive/MyDrive/final project dls/streamlit_app/demo.py' & npx localtunnel --port 8501
# Out:
# ⠙
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.16.129.33:8501
#
# your url is: https://open-seas-lead.loca.lt
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   128 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:669 in code_to_exec
#
#   /content/gdrive/MyDrive/final project dls/streamlit_app/demo.py:12 in <module>
#
#      9 st.header("Рассчёт площади застройки территории по снимку", divider="gray", wid
#     10 DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#     11 model = UNet().to(DEVICE)
#   ❱ 12 checkpoints = load_model()
#     13 model.load_state_dict(checkpoints['model_state_dict'])
#     14 model.eval()
#     15
#
# ...
